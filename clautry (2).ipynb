# %%
print("Hi this is me trying")
# Out:
# Hi this is me trying

# %%
import pandas as pd
print("Pandas is ready!")
# Out:
# Pandas is ready!

# %%
data=({'Name':['Amit','Priya','Ravi','Sneha','Pooja'],"Department":['HR','IT','Finance','IT','HR'],"Salary":[45000,72000,61000,85000,39000],
       "City":['Mumbai','Bangalore','Delhi','Mumbai','Pune']})
df=pd.DataFrame(data)
print(df)
# Out:
#     Name Department  Salary       City
# 0   Amit         HR   45000     Mumbai
# 1  Priya         IT   72000  Bangalore
# 2   Ravi    Finance   61000      Delhi
# 3  Sneha         IT   85000     Mumbai
# 4  Pooja         HR   39000       Pune

# %%
df.head()
# Out:
#     Name Department  Salary       City
# 0   Amit         HR   45000     Mumbai
# 1  Priya         IT   72000  Bangalore
# 2   Ravi    Finance   61000      Delhi
# 3  Sneha         IT   85000     Mumbai
# 4  Pooja         HR   39000       Pune

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Department', 'Salary', 'City'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
#  3   City        5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
df['Salary'].sum()
# Out:
# np.int64(302000)

# %%
df['Salary'].mean()
# Out:
# np.float64(60400.0)

# %%
df['Salary'].max()
# Out:
# 85000

# %%
df['Salary'].min()
# Out:
# 39000

# %%
df['Salary'].count()
# Out:
# np.int64(5)

# %%
df.groupby("Department")["Salary"].sum()
# Out:
# Department
# Finance     61000
# HR          84000
# IT         157000
# Name: Salary, dtype: int64

# %%
df.groupby("Department")['Salary'].mean()
# Out:
# Department
# Finance    61000.0
# HR         42000.0
# IT         78500.0
# Name: Salary, dtype: float64

# %%
df.groupby("City")['Salary'].max()
# Out:
# City
# Bangalore    72000
# Delhi        61000
# Mumbai       85000
# Pune         39000
# Name: Salary, dtype: int64

# %%
df.groupby("Department")['Name'].count()
# Out:
# Department
# Finance    1
# HR         2
# IT         2
# Name: Name, dtype: int64

# %%
df[df["Salary"]>60000]
# Out:
#     Name Department  Salary       City
# 1  Priya         IT   72000  Bangalore
# 2   Ravi    Finance   61000      Delhi
# 3  Sneha         IT   85000     Mumbai

# %%
df[df["City"] =="Mumbai"]
# Out:
#     Name Department  Salary    City
# 0   Amit         HR   45000  Mumbai
# 3  Sneha         IT   85000  Mumbai

# %%
df[df["Department"]=="IT"]
# Out:
#     Name Department  Salary       City
# 1  Priya         IT   72000  Bangalore
# 3  Sneha         IT   85000     Mumbai

# %%
df[(df["Salary"]>60000) & (df["City"]=="Mumbai")]
# Out:
#     Name Department  Salary    City
# 3  Sneha         IT   85000  Mumbai

# %%
df[(df["Department"] == "HR") | (df["City"] == "Delhi")]
# Out:
#     Name Department  Salary    City
# 0   Amit         HR   45000  Mumbai
# 2   Ravi    Finance   61000   Delhi
# 4  Pooja         HR   39000    Pune

# %%
df.sort_values("Salary")
# Out:
#     Name Department  Salary       City
# 4  Pooja         HR   39000       Pune
# 0   Amit         HR   45000     Mumbai
# 2   Ravi    Finance   61000      Delhi
# 1  Priya         IT   72000  Bangalore
# 3  Sneha         IT   85000     Mumbai

# %%
df.sort_values("Salary", ascending=False)
# Out:
#     Name Department  Salary       City
# 3  Sneha         IT   85000     Mumbai
# 1  Priya         IT   72000  Bangalore
# 2   Ravi    Finance   61000      Delhi
# 0   Amit         HR   45000     Mumbai
# 4  Pooja         HR   39000       Pune

# %%
df[["Name","Salary"]]
# Out:
#     Name  Salary
# 0   Amit   45000
# 1  Priya   72000
# 2   Ravi   61000
# 3  Sneha   85000
# 4  Pooja   39000

# %%
df["Department"].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)
